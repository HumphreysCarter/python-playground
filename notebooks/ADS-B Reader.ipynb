# %%
import pandas as pd

# %% [markdown]
# ### Read in Aircraft List

# %%
df=pd.read_json('http://carterhumphreys.com/ads-b/aircraft.json')
df['now'][0]
# Out:
# 1585777141

# %% [markdown]
# ### Extract ADS-B Data from Aircraft List

# %%
df=pd.DataFrame(df['aircraft'].tolist())
df
# Out:
#        hex  alt_baro  alt_geom     gs  track  baro_rate  nav_qnh  \
# 0   a54aae   36000.0   35525.0  444.6  334.7        0.0   1013.6
# 1   ad2062   26925.0   26300.0  419.3  294.7     1792.0      NaN
# 2   aa9e6d   40975.0   40700.0  462.3   85.7        0.0   1013.6
# 3   a491f1   38000.0   37650.0  444.8  278.4       64.0   1013.6
# 4   a55f31       NaN       NaN    NaN    NaN        NaN      NaN
# 5   adf128   38000.0   37600.0  440.7  231.7       64.0      NaN
# 6   a8795a   24700.0   24775.0  458.1  105.7    -1664.0   1013.6
# 7   a64d9f   17975.0   17525.0  411.3   16.7    -1984.0   1012.0
# 8   a2c635   40000.0   39600.0  408.4  259.8        0.0   1013.6
# 9   a894aa   24875.0   24475.0  478.5   95.9    -3008.0   1017.6
# 10  abd50f       NaN       NaN    NaN    NaN        NaN      NaN
# 11  a144e5   35000.0   34425.0  484.3   77.6       64.0   1012.8
# 12  a83dc1       NaN       NaN    NaN    NaN        NaN      NaN
# ...

# %%
lat = df['lat'].values
lon = df['lon'].values
alt = df['alt_baro'].values
